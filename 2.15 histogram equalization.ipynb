# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
# 4X4 이미지 - 0~7까지 8단계로 구성함
src = np.array([[0, 0, 0, 0],
              [1, 1, 3, 5],
              [6, 1, 1, 3],
              [4, 3, 1, 7]
              ], dtype=np.uint8)

dst = cv2.equalizeHist(src)
print('dst = ', dst)
# Out:
# dst =  [[  0   0   0   0]
#  [106 106 170 212]
#  [234 106 106 170]
#  [191 170 106 255]]

# %%
src = cv2.imread('./data/lena.jpg', cv2.IMREAD_GRAYSCALE) #반드시 gray로!
dst = cv2.equalizeHist(src)
cv2.imshow('src',src)
cv2.imshow('dst', dst)
cv2.waitKey()    
cv2.destroyAllWindows()

# %%
plt.title('Grayscale histogram of lena.jpg')
hist1 = cv2.calcHist(images=[src], channels=[0], mask=None, 
                     histSize=[256], ranges=[0, 256])
plt.plot(hist1, color='b', label = 'hist1 in src')

# 히스토그램 평활화 - 분포를 넓게 퍼지게 해줌!!
hist2 = cv2.calcHist(images=[dst], channels=[0], mask=None, 
                     histSize=[256], ranges=[0, 256])
plt.plot(hist2, color='r', alpha = 0.7, label = 'hist2 in dst')
plt.legend(loc='best')
plt.show()

# %%
src = cv2.imread('./data/lena.jpg')

#1 v - 명도
hsv = cv2.cvtColor(src, cv2.COLOR_BGR2HSV)
h,s,v = cv2.split(hsv)
v2 = cv2.equalizeHist(v)
hsv2 = cv2.merge([h,s,v2])
dst = cv2.cvtColor(hsv2, cv2.COLOR_HSV2BGR)

#2 y - 휘도
yCrCv = cv2.cvtColor(src, cv2.COLOR_BGR2YCrCb)
y,Cr,Cv = cv2.split(yCrCv)
y2 = cv2.equalizeHist(y)
yCrCv2 = cv2.merge([y2, Cr, Cv])
dst2 = cv2.cvtColor(yCrCv2, cv2.COLOR_YCrCb2BGR)

cv2.imshow('src',src)
cv2.imshow('dst', dst)
cv2.imshow('dst2', dst2)
cv2.waitKey()    
cv2.destroyAllWindows()
